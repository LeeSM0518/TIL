# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get('http://naver.com')

# %%
driver.save_screenshot('./images/001.jpg')
# Out:
# True

# %%
elem_login = driver.find_element_by_id("id")
elem_login.clear()
elem_login.send_keys('nalsm98')

elem_login = driver.find_element_by_id("pw")
elem_login.clear()
elem_login.send_keys('Leesm0518!!')

# %%
xpath = '''//*[@id="frmNIDLogin"]/fieldset/input'''
driver.find_element_by_xpath(xpath).click()

# %%
driver.get('http://mail.naver.com')

# %%
from bs4 import BeautifulSoup

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
raw_list = soup.find_all('div', 'name _ccr(lst.from) ')
raw_list
# Out:
# [<div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24347) _stopDefault" href="#" title='"한국장학재단" &lt;icl@kosaf.go.kr&gt;'>한국장학재단</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24346) _stopDefault" href="#" title='"온투데이" &lt;mail2@dbsmedia.co.kr&gt;'>온투데이</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24345) _stopDefault" href="#" title='"김경아" &lt;sueich_01@naver.com&gt;'>김경아</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24344) _stopDefault" href="#" title='"Microsoft" &lt;microsoft@e-mail.microsoft.com&gt;'>Microsoft</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24343) _stopDefault" href="#" title='"Microsoft" &lt;microsoft@e-mail.microsoft.com&gt;'>Microsoft</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24342) _stopDefault" href="#" title='"마이민트" &lt;mimint_event@mimint.co.kr&gt;'>마이민트</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24341) _stopDefault" href="#" title='"G마켓" &lt;mailmaster@corp.gmarket.co.kr&gt;'>G마켓</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24340) _stopDefault" href="#" title='"쿠팡" &lt;noreply@e.coupang.com&gt;'>쿠팡</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24339) _stopDefault" href="#" title='"G마켓 슈퍼딜" &lt;mailmaster@corp.gmarket.co.kr&gt;'>G마켓 슈퍼딜</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24337) _stopDefault" href="#" title='"마이민트" &lt;mimint_event@mimint.co.kr&gt;'>마이민트</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24336) _stopDefault" href="#" title='"G마켓 푸드데이" &lt;mailmaster@corp.gmarket.co.kr&gt;'>G마켓 푸드데이</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24335) _stopDefault" href="#" title='"[CJ ONE]" &lt;webmaster@cjone.com&gt;'>[CJ ONE]</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24334) _stopDefault" href="#" title='"온투데이" &lt;mail2@dbsmedia.co.kr&gt;'>온투데이</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24333) _stopDefault" href="#" title='"희망서비스" &lt;wjsansrk005@daum.net&gt;'>희망서비스</a></div>,
#  <div class="name _ccr(lst.from) "><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|24332) _stopDefault" href="#" title='"Microsoft" &lt;microsoft@e-mail.microsoft.com&gt;'>Microsoft</a></div>]

# %%
send_list = [raw_list[n].find('a').get_text() for n in range(0, len(raw_list))]
send_list
# Out:
# ['한국장학재단',
#  '온투데이',
#  '김경아',
#  'Microsoft',
#  'Microsoft',
#  '마이민트',
#  'G마켓',
#  '쿠팡',
#  'G마켓 슈퍼딜',
#  '마이민트',
#  'G마켓 푸드데이',
#  '[CJ ONE]',
#  '온투데이',
#  '희망서비스',
#  'Microsoft']

# %%
driver.close()

# %%
driver = webdriver.Chrome('./chromedriver.exe')

# %%
driver.get('http://www.opinet.co.kr/searRgSelect.do')

# %%
gu_list_raw = driver.find_element_by_xpath('''//*[@id="SIGUNGU_NM0"]''')
gu_list = gu_list_raw.find_elements_by_tag_name('option')

# %%
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id("SIGUNGU_NM0")
element.send_keys(gu_names[0])

# %%
xpath = '''//*[@id="searRgSelect"]'''
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = """//*[@id="glopopd_excel"]"""
element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-33-ad0c9a213c39> in <module>
# ----> 1 driver.close()
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609538 (b655c5a60b0b544917107a59d4153d4bf78e1b90),platform=Windows NT 10.0.17134 x86_64)

# %%
import time
from tqdm import tqdm_notebook

for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    time.sleep(2)
    
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
    
    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)

# %%
import pandas as pd
from glob import glob

# %%
glob('./DataScience/data/지역*.xls')
# Out:
# ['./DataScience/data\\지역_위치별(주유소) (1).xls',
#  './DataScience/data\\지역_위치별(주유소) (10).xls',
#  './DataScience/data\\지역_위치별(주유소) (11).xls',
#  './DataScience/data\\지역_위치별(주유소) (12).xls',
#  './DataScience/data\\지역_위치별(주유소) (13).xls',
#  './DataScience/data\\지역_위치별(주유소) (14).xls',
#  './DataScience/data\\지역_위치별(주유소) (15).xls',
#  './DataScience/data\\지역_위치별(주유소) (16).xls',
#  './DataScience/data\\지역_위치별(주유소) (17).xls',
#  './DataScience/data\\지역_위치별(주유소) (18).xls',
#  './DataScience/data\\지역_위치별(주유소) (19).xls',
#  './DataScience/data\\지역_위치별(주유소) (2).xls',
#  './DataScience/data\\지역_위치별(주유소) (20).xls',
#  './DataScience/data\\지역_위치별(주유소) (21).xls',
#  './DataScience/data\\지역_위치별(주유소) (22).xls',
#  './DataScience/data\\지역_위치별(주유소) (23).xls',
#  './DataScience/data\\지역_위치별(주유소) (24).xls',
#  './DataScience/data\\지역_위치별(주유소) (3).xls',
#  './DataScience/data\\지역_위치별(주유소) (4).xls',
#  './DataScience/data\\지역_위치별(주유소) (5).xls',
#  './DataScience/data\\지역_위치별(주유소) (6).xls',
#  './DataScience/data\\지역_위치별(주유소) (7).xls',
#  './DataScience/data\\지역_위치별(주유소) (8).xls',
#  './DataScience/data\\지역_위치별(주유소) (9).xls',
#  './DataScience/data\\지역_위치별(주유소).xls']

# %%
stations_files = glob('./DataScience/data/지역*.xls')
stations_files
# Out:
# ['./DataScience/data\\지역_위치별(주유소) (1).xls',
#  './DataScience/data\\지역_위치별(주유소) (10).xls',
#  './DataScience/data\\지역_위치별(주유소) (11).xls',
#  './DataScience/data\\지역_위치별(주유소) (12).xls',
#  './DataScience/data\\지역_위치별(주유소) (13).xls',
#  './DataScience/data\\지역_위치별(주유소) (14).xls',
#  './DataScience/data\\지역_위치별(주유소) (15).xls',
#  './DataScience/data\\지역_위치별(주유소) (16).xls',
#  './DataScience/data\\지역_위치별(주유소) (17).xls',
#  './DataScience/data\\지역_위치별(주유소) (18).xls',
#  './DataScience/data\\지역_위치별(주유소) (19).xls',
#  './DataScience/data\\지역_위치별(주유소) (2).xls',
#  './DataScience/data\\지역_위치별(주유소) (20).xls',
#  './DataScience/data\\지역_위치별(주유소) (21).xls',
#  './DataScience/data\\지역_위치별(주유소) (22).xls',
#  './DataScience/data\\지역_위치별(주유소) (23).xls',
#  './DataScience/data\\지역_위치별(주유소) (24).xls',
#  './DataScience/data\\지역_위치별(주유소) (3).xls',
#  './DataScience/data\\지역_위치별(주유소) (4).xls',
#  './DataScience/data\\지역_위치별(주유소) (5).xls',
#  './DataScience/data\\지역_위치별(주유소) (6).xls',
#  './DataScience/data\\지역_위치별(주유소) (7).xls',
#  './DataScience/data\\지역_위치별(주유소) (8).xls',
#  './DataScience/data\\지역_위치별(주유소) (9).xls',
#  './DataScience/data\\지역_위치별(주유소).xls']

# %%
tmp_raw = []

for file_name in stations_files:
    tmp = pd.read_excel(file_name, header = 2)
    tmp_raw.append(tmp)

station_raw = pd.concat(tmp_raw)

# %%
station_raw
# Out:
#        지역                    상호                            주소      상표  \
# 0   서울특별시                오렌지주유소          서울 강동구 성안로 102 (성내동)   SK에너지
# 1   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2   서울특별시        GS칼텍스㈜직영 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 3   서울특별시                 광성주유소         서울 강동구 올림픽로 673 (천호동)   S-OIL
# 4   서울특별시   (주)소모에너지엔테크놀러지성내주유소         서울 강동구 올림픽로 578 (성내동)   GS칼텍스
# 5   서울특별시       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)   S-OIL
# 6   서울특별시          알이디씨(주)천동주유소     서울특별시 강동구  천호대로 987 (천호동)  현대오일뱅크
# 7   서울특별시              sk해뜨는주유소      서울특별시 강동구  상일로 132 (강일동)   SK에너지
# 8   서울특별시        대성석유(주)직영길동주유소        서울 강동구 천호대로 1168 (둔촌동)   GS칼텍스
# 9   서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)   SK에너지
# 10  서울특별시    SK네트웍스㈜암사주유소(self)         서울 강동구 올림픽로 749 (암사동)   SK에너지
# 11  서울특별시        (주)삼표에너지 고덕주유소           서울 강동구 고덕로 39 (암사동)   GS칼텍스
# 12  서울특별시    CJ대한통운(주)직영 천호점주유소           서울 강동구 천중로 67 (천호동)  현대오일뱅크
# 13  서울특별시        SK네트윅스(주)길동주유소         서울 강동구 천호대로 1221 (길동)   SK에너지
# 14  서울특별시               고속셀프주유소    서울특별시 강동구  천호대로 1246 (둔촌동)   SK에너지
# 15  서울특별시        SK네트윅스(주)한미주유소           서울 강동구 성내로 32 (성내동)   SK에너지
# 16  서울특별시                 명일주유소          서울 강동구 고덕로 168 (명일동)   SK에너지
# 17  서울특별시                 강동주유소         서울 강동구 양재대로 1509 (길동)   SK에너지
# 18  서울특별시         명진석유(주)동서울주유소    서울특별시 강동구  천호대로 1456 (상일동)   GS칼텍스
# 0   서울특별시               SK경동주유소         서울 동대문구 이문로 191 (이문동)   SK에너지
# 1   서울특별시       삼미상사(주)장안킹셀프주유소     서울특별시 동대문구  한천로 100 (장안동)   SK에너지
# 2   서울특별시                 웰컴주유소     서울특별시 동대문구  한천로 414 (이문동)  현대오일뱅크
# 3   서울특별시              (주)열린주유소         서울 동대문구 한천로 263 (휘경동)   GS칼텍스
# 4   서울특별시               재정제2주유소         서울 동대문구 사가정로 90 (전농동)  현대오일뱅크
# 5   서울특별시         재원에너지(주)용일주유소          서울 동대문구 안암로 54 (용두동)   GS칼텍스
# 6   서울특별시                 풍한주유소     서울특별시 동대문구  안암로 168 (제기동)   SK에너지
# 7   서울특별시                 삼영주유소        서울 동대문구 답십리로 258 (장안동)   SK에너지
# 8   서울특별시                 재정주유소         서울 동대문구 전농로 121 (전농동)  현대오일뱅크
# 9   서울특별시          동일석유(주)강남주유소    서울특별시 동대문구  사가정로 103 (전농동)   SK에너지
# 10  서울특별시                답십리주유소       서울 동대문구 답십리로 223 (답십리동)   GS칼텍스
# ..    ...                   ...                           ...     ...
# 16  서울특별시                 역삼주유소      서울특별시 강남구  논현로 426 (역삼동)   GS칼텍스
# 17  서울특별시                삼성로주유소      서울특별시 강남구  삼성로 563 (삼성동)   GS칼텍스
# 18  서울특별시             SK서광그린주유소       서울특별시 강남구 봉은사로 222(역삼동)   SK에너지
# 19  서울특별시                 일원주유소        서울 강남구 양재대로55길 3 (일원동)   S-OIL
# 20  서울특별시       동일석유(주)대치동셀프주유소         서울 강남구 영동대로 202 (대치동)   SK에너지
# 21  서울특별시        동일석유(주)직영남부주유소           서울 강남구 선릉로 34 (개포동)   SK에너지
# 22  서울특별시              (주)새서울석유         서울 강남구 압구정로 154 (신사동)  현대오일뱅크
# 23  서울특별시                 대교주유소         서울 강남구 강남대로 640 (신사동)   SK에너지
# 24  서울특별시             현대오일뱅크(주)         서울 강남구 도산대로 163 (신사동)  현대오일뱅크
# 25  서울특별시        일진실업(주)스포월드주유소          서울 강남구 언주로 559 (역삼동)   GS칼텍스
# 26  서울특별시                 대청주유소          서울 강남구 개포로 654 (일원동)   SK에너지
# 27  서울특별시                 은마주유소         서울 강남구 영동대로 235 (대치동)   GS칼텍스
# 28  서울특별시                 논현주유소          서울 강남구 논현로 747 (논현동)   SK에너지
# 29  서울특별시  (주)소모에너지엔테크놀러지쎈트럴주유소          서울 강남구 삼성로 335 (대치동)   GS칼텍스
# 30  서울특별시     현대오일뱅크(주)직영 한양주유소         서울 강남구 압구정로 302 (신사동)  현대오일뱅크
# 31  서울특별시          대성석유(주)동호주유소  서울특별시 강남구  봉은사로113길 51 (삼성동)   GS칼텍스
# 32  서울특별시              지에스타워주유소      서울특별시 강남구  논현로 516 (역삼동)   GS칼텍스
# 33  서울특별시                 명품주유소          서울 강남구 도곡로 249 (역삼동)   S-OIL
# 34  서울특별시                학여울주유소       서울 강남구 남부순환로 3170 (대치동)   GS칼텍스
# 35  서울특별시                 주성주유소     서울특별시 강남구  영동대로 716 (청담동)   GS칼텍스
# 36  서울특별시              (주)만정에너지         서울 강남구 봉은사로 433 (삼성동)   GS칼텍스
# 37  서울특별시       sk네트웍스(주)진달래주유소      서울특별시 강남구  도곡로 208 (도곡동)   SK에너지
# 38  서울특별시                    금성         서울 강남구 테헤란로 619 (삼성동)   SK에너지
# 39  서울특별시                  선우상사       서울 강남구 남부순환로 2651 (도곡동)   SK에너지
# 40  서울특별시                 경원주유소         서울 강남구 도산대로 428 (청담동)   S-OIL
# 41  서울특별시               갤러리아주유소         서울 강남구 압구정로 426 (청담동)   SK에너지
# 42  서울특별시                 동우주유소     서울특별시 강남구  봉은사로 311 (논현동)   SK에너지
# 43  서울특별시                 삼성주유소          서울 강남구 삼성로 521 (삼성동)   SK에너지
# 44  서울특별시                 오천주유소         서울 강남구 봉은사로 503 (삼성동)   SK에너지
# 45  서울특별시               뉴서울(강남)          서울 강남구 언주로 716 (논현동)   SK에너지
#
#              전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0     02-484-6165    N     -  1554  1354   997
# 1     02-441-0536    N     -  1556  1355     -
# 2     02-475-2600    N  1855  1559  1349  1000
# 3     02-470-5133    N     -  1578  1388  1100
# 4     02-479-3838    Y     -  1588  1388     -
# 5     02-484-1162    Y     -  1588  1388     -
# 6     02-473-1556    N     -  1598  1398  1000
# 7     02-442-7801    Y     -  1598  1398  1000
# 8     02-474-7222    N  1857  1599  1398  1000
# 9     02-442-5145    Y     -  1608  1398   990
# 10   02-3427-2043    Y  1887  1653  1463     -
# 11    02-441-3327    N  1869  1669  1469  1180
# 12    02-473-5189    N     -  1697  1499  1100
# 13    02-488-3491    Y  1889  1733  1533     -
# 14    02-487-2030    Y  1889  1733  1533  1157
# 15    02-473-1981    N     -  1763  1563  1006
# 16   02-3428-1739    N  1914  1764  1574     -
# 17    02-477-5101    N  2258  1983  1784  1289
# 18    02-427-5230    Y     -     -     -     -
# 0     02-962-5188    N     -  1515  1305  1100
# 1    02-2242-7115    Y     -  1515  1305     -
# 2     02-969-1144    N     -  1515  1305     -
# 3   070-4413-6542    N     -  1515  1305  1100
# 4    02-2249-6682    Y     -  1519  1319     -
# 5    02-3291-5151    N     -  1522  1313     -
# 6     02-924-5189    N     -  1525  1315     -
# 7    02-2217-2017    N     -  1529  1329  1100
# 8   070-8256-4617    N     -  1529  1319  1100
# 9    02-3394-5183    N     -  1529  1329  1100
# 10   02-2213-9901    N     -  1529  1329     -
# ..            ...  ...   ...   ...   ...   ...
# 16    02-548-5145    N  1833  1633  1399   850
# 17    02-538-5138    Y  1795  1639  1443     -
# 18    02-566-4855    N  1885  1685  1485  1050
# 19   02-2226-5188    Y     -  1688  1438     -
# 20    02-566-3037    Y  1998  1688  1438  1119
# 21    02-576-7447    N     -  1728  1528     -
# 22    02-543-1154    N  1987  1757  1543     -
# 23    02-512-5521    N  1990  1780  1580     -
# 24    02-546-2182    N  1998  1785  1584     -
# 25    02-508-7021    N  2061  1823  1653  1024
# 26    02-445-5500    N  2079  1859  1639  1399
# 27   02-3452-1882    N  2027  1863  1635     -
# 28    02-511-0955    N  1998  1865  1651  1198
# 29    02-565-0267    N  2088  1883  1672  1203
# 30   02-3444-0804    N  1998  1890  1598     -
# 31    02-545-0720    N  2097  1897  1697     -
# 32    02-539-5145    N  2189  1937  1738     -
# 33    02-501-1256    N  2098  1953  1733     -
# 34   02-3411-3271    N  2165  1976  1754     -
# 35    02-518-3460    N  2179  1998  1798     -
# 36    02-518-5141    N  2285  1999  1885  1207
# 37   02-3462-0018    N  2149  1999  1799     -
# 38    02-508-6572    N  2126  2006  1809     -
# 39   02-3462-5100    N  2278  2028  1897     -
# 40    02-517-1957    N  2263  2055  1867     -
# 41    02-540-4965    N  2268  2059  1869  1206
# 42    02-542-6726    N  2306  2105  1908     -
# 43    02-538-0809    N  2305  2106  1909  1189
# 44    02-545-2822    N  2293  2107  1909  1232
# 45    02-518-5631    N  2420  2120  1920  1330
#
# [537 rows x 10 columns]

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 537 entries, 0 to 45
# Data columns (total 10 columns):
# 지역       537 non-null object
# 상호       537 non-null object
# 주소       537 non-null object
# 상표       537 non-null object
# 전화번호     537 non-null object
# 셀프여부     537 non-null object
# 고급휘발유    537 non-null object
# 휘발유      537 non-null object
# 경유       537 non-null object
# 실내등유     537 non-null object
# dtypes: object(10)
# memory usage: 25.2+ KB

# %%
station_raw.head()
# Out:
#       지역                   상호                      주소      상표         전화번호  \
# 0  서울특별시               오렌지주유소    서울 강동구 성안로 102 (성내동)   SK에너지  02-484-6165
# 1  서울특별시               구천면주유소   서울 강동구 구천면로 357 (암사동)  현대오일뱅크  02-441-0536
# 2  서울특별시       GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)   GS칼텍스  02-475-2600
# 3  서울특별시                광성주유소   서울 강동구 올림픽로 673 (천호동)   S-OIL  02-470-5133
# 4  서울특별시  (주)소모에너지엔테크놀러지성내주유소   서울 강동구 올림픽로 578 (성내동)   GS칼텍스  02-479-3838
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    N     -  1554  1354   997
# 1    N     -  1556  1355     -
# 2    N  1855  1559  1349  1000
# 3    N     -  1578  1388  1100
# 4    Y     -  1588  1388     -

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'], 
                                       '주소':station_raw['주소'],
                                       '가격':station_raw['휘발유'],
                                       '셀프':station_raw['셀프여부'],
                                       '상표':station_raw['상표']  })
stations.head()
# Out:
#              Oil_store                      주소    가격 셀프      상표
# 0               오렌지주유소    서울 강동구 성안로 102 (성내동)  1554  N   SK에너지
# 1               구천면주유소   서울 강동구 구천면로 357 (암사동)  1556  N  현대오일뱅크
# 2       GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)  1559  N   GS칼텍스
# 3                광성주유소   서울 강동구 올림픽로 673 (천호동)  1578  N   S-OIL
# 4  (주)소모에너지엔테크놀러지성내주유소   서울 강동구 올림픽로 578 (성내동)  1588  Y   GS칼텍스

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#              Oil_store                      주소    가격 셀프      상표    구
# 0               오렌지주유소    서울 강동구 성안로 102 (성내동)  1554  N   SK에너지  강동구
# 1               구천면주유소   서울 강동구 구천면로 357 (암사동)  1556  N  현대오일뱅크  강동구
# 2       GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)  1559  N   GS칼텍스  강동구
# 3                광성주유소   서울 강동구 올림픽로 673 (천호동)  1578  N   S-OIL  강동구
# 4  (주)소모에너지엔테크놀러지성내주유소   서울 강동구 올림픽로 578 (성내동)  1588  Y   GS칼텍스  강동구

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '서울특별시', '성북구',
#        '송파구', '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구',
#        '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '특별시', '강남구'],
#       dtype=object)

# %%
stations[stations['구'] == '서울특별시']
# Out:
#          Oil_store                           주소    가격 셀프     상표      구
# 12  SK네트웍스(주)효진주유소  1 서울특별시 성동구 동일로 129 (성수동2가)  1654  N  SK에너지  서울특별시

# %%
stations.loc[stations['구'] == '서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '특별시', '강남구'],
#       dtype=object)

# %%
stations[stations['구'] == '특별시']
# Out:
#    Oil_store                        주소    가격 셀프     상표    구
# 10     서현주유소  서울 특별시 도봉구 방학로 142 (방학동)  1524  Y  S-OIL  특별시

# %%
stations.loc[stations['구'] == '특별시', '구'] = '도봉구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations[stations['가격'] =='-']
# Out:
#         Oil_store                          주소 가격 셀프     상표     구
# 18  명진석유(주)동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)  -  Y  GS칼텍스   강동구
# 33          하나주유소   서울특별시 영등포구  도림로 236 (신길동)  -  N  S-OIL  영등포구
# 12   (주)에이앤이청담주유소    서울특별시 강북구 도봉로 155  (미아동)  -  Y  SK에너지   강북구
# 13          송정주유소    서울특별시 강북구 인수봉로 185 (수유동)  -  N   자가상표   강북구

# %%
stations = stations[stations['가격'] !='-']
stations.head()
# Out:
#              Oil_store                      주소    가격 셀프      상표    구
# 0               오렌지주유소    서울 강동구 성안로 102 (성내동)  1554  N   SK에너지  강동구
# 1               구천면주유소   서울 강동구 구천면로 357 (암사동)  1556  N  현대오일뱅크  강동구
# 2       GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)  1559  N   GS칼텍스  강동구
# 3                광성주유소   서울 강동구 올림픽로 673 (천호동)  1578  N   S-OIL  강동구
# 4  (주)소모에너지엔테크놀러지성내주유소   서울 강동구 올림픽로 578 (성내동)  1588  Y   GS칼텍스  강동구

# %%
stations['가격'] = [float(value) for value in stations['가격']]

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 533 entries, 0 to 532
# Data columns (total 6 columns):
# Oil_store    533 non-null object
# 주소           533 non-null object
# 가격           533 non-null float64
# 셀프           533 non-null object
# 상표           533 non-null object
# 구            533 non-null object
# dtypes: float64(1), object(5)
# memory usage: 14.6+ KB
